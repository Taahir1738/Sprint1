# %%
#Scatter plot
#Chips
import matplotlib.pyplot as plt

x = ["Simba","Lays","Willards","Pringles","Doritos","Nik Naks","IQ Foods","Walkers","Truda"]
y = [2,4,6,8,10,14,9,10,12]

plt.scatter(x, y)
plt.show()

# %%
#Bar graph
#Cooldrinks
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('Coke','Fanta','Jive','Tab','Sprite','Stoney','Scheppes','Twizza','Cape Cola')
y_pos = np.arange(len(objects))
performance = [20,15,10,8,13,5,3,5,6]

plt.bar(y_pos, performance, align='center', alpha=1.0)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
#Line graph
#Chocolates
import matplotlib.pyplot as plt
x = ['Cadbury','Snickers','Lindt','Ferrero Roche','Nestle','Toblerone','Godiva','Kit Kat','De Villiers','Merci']
y = [18,20,15,10,15,9,8,18,9,8]
plt.plot(x,y)
plt.show()
